# %% [markdown]
# # Building user-based recommendation model for Amazon

# %% [markdown]
# ## DESCRIPTION
#
# The dataset provided contains movie reviews given by Amazon customers. Reviews were given between May 1996 and July 2014.
#
# ### Data Dictionary
# UserID – 4848 customers who provided a rating for each movie
# Movie 1 to Movie 206 – 206 movies for which ratings are provided by 4848 distinct users
#
# ### Data Considerations
# - All the users have not watched all the movies and therefore, all movies are not rated. These missing values are represented by NA.
# - Ratings are on a scale of -1 to 10 where -1 is the least rating and 10 is the best.
#
# ### Analysis Task
# - ##### Exploratory Data Analysis:
# >- Which movies have maximum views/ratings?
# >- What is the average rating for each movie? Define the top 5 movies with the maximum ratings.
# >- Define the top 5 movies with the least audience.
# - ##### Recommendation Model: Some of the movies hadn’t been watched and therefore, are not rated by the users. Netflix would like to take this as an opportunity and build a machine learning recommendation algorithm which provides the ratings for each of the users.
# >- Divide the data into training and test data
# >- Build a recommendation model on training data
# >- Make predictions on the test data

# %% [markdown]
# ### Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

pd.pandas.set_option('display.max_columns',None)

# %% [markdown]
# ### Loading the data

# %%
amazon_data=pd.read_csv('Amazon - Movies and TV Ratings.csv')
amazon_data.head()
# Out:
#           user_id  Movie1  Movie2  Movie3  Movie4  Movie5  Movie6  Movie7  \
# 0  A3R5OBKS7OM2IR     5.0     5.0     NaN     NaN     NaN     NaN     NaN
# 1   AH3QC2PC1VTGP     NaN     NaN     2.0     NaN     NaN     NaN     NaN
# 2  A3LKP6WPMP9UKX     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 3   AVIY68KEPQ5ZD     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 4  A1CV1WROP5KTTW     NaN     NaN     NaN     NaN     5.0     NaN     NaN
#
#    Movie8  Movie9  Movie10  Movie11  Movie12  Movie13  Movie14  Movie15  \
# 0     NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1     NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2     NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3     NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4     NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Movie16  Movie17  Movie18  Movie19  Movie20  Movie21  Movie22  Movie23  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Movie24  Movie25  Movie26  Movie27  Movie28  Movie29  Movie30  Movie31  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Movie32  Movie33  Movie34  Movie35  Movie36  Movie37  Movie38  Movie39  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Movie40  Movie41  Movie42  Movie43  Movie44  Movie45  Movie46  Movie47  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Movie48  Movie49  Movie50  Movie51  Movie52  Movie53  Movie54  Movie55  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Movie56  Movie57  Movie58  Movie59  Movie60  Movie61  Movie62  Movie63  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Movie64  Movie65  Movie66  Movie67  Movie68  Movie69  Movie70  Movie71  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Movie72  Movie73  Movie74  Movie75  Movie76  Movie77  Movie78  Movie79  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Movie80  Movie81  Movie82  Movie83  Movie84  Movie85  Movie86  Movie87  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Movie88  Movie89  Movie90  Movie91  Movie92  Movie93  Movie94  Movie95  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Movie96  Movie97  Movie98  Movie99  Movie100  Movie101  Movie102  Movie103  \
# 0      NaN      NaN      NaN      NaN       NaN       NaN       NaN       NaN
# 1      NaN      NaN      NaN      NaN       NaN       NaN       NaN       NaN
# 2      NaN      NaN      NaN      NaN       NaN       NaN       NaN       NaN
# 3      NaN      NaN      NaN      NaN       NaN       NaN       NaN       NaN
# 4      NaN      NaN      NaN      NaN       NaN       NaN       NaN       NaN
#
#    Movie104  Movie105  Movie106  Movie107  Movie108  Movie109  Movie110  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Movie111  Movie112  Movie113  Movie114  Movie115  Movie116  Movie117  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Movie118  Movie119  Movie120  Movie121  Movie122  Movie123  Movie124  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Movie125  Movie126  Movie127  Movie128  Movie129  Movie130  Movie131  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Movie132  Movie133  Movie134  Movie135  Movie136  Movie137  Movie138  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Movie139  Movie140  Movie141  Movie142  Movie143  Movie144  Movie145  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Movie146  Movie147  Movie148  Movie149  Movie150  Movie151  Movie152  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Movie153  Movie154  Movie155  Movie156  Movie157  Movie158  Movie159  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Movie160  Movie161  Movie162  Movie163  Movie164  Movie165  Movie166  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Movie167  Movie168  Movie169  Movie170  Movie171  Movie172  Movie173  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Movie174  Movie175  Movie176  Movie177  Movie178  Movie179  Movie180  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Movie181  Movie182  Movie183  Movie184  Movie185  Movie186  Movie187  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Movie188  Movie189  Movie190  Movie191  Movie192  Movie193  Movie194  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Movie195  Movie196  Movie197  Movie198  Movie199  Movie200  Movie201  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Movie202  Movie203  Movie204  Movie205  Movie206
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN

# %%
amazon_data.shape
# Out:
# (4848, 207)

# %%
amazon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4848 entries, 0 to 4847
# Columns: 207 entries, user_id to Movie206
# dtypes: float64(206), object(1)
# memory usage: 7.7+ MB

# %% [markdown]
# ### Checking for missing values

# %%
missing_val=[cols for cols in amazon_data.columns if amazon_data[cols].isnull().sum()>0]
for cols in missing_val:
    print('{} as {}% of missing values in it'.format(cols,np.round(amazon_data[cols].isnull().mean(),4)))
# Out:
# Movie1 as 0.9998% of missing values in it
# Movie2 as 0.9998% of missing values in it
# Movie3 as 0.9998% of missing values in it
# Movie4 as 0.9996% of missing values in it
# Movie5 as 0.994% of missing values in it
# Movie6 as 0.9998% of missing values in it
# Movie7 as 0.9998% of missing values in it
# Movie8 as 0.9998% of missing values in it
# Movie9 as 0.9998% of missing values in it
# Movie10 as 0.9998% of missing values in it
# Movie11 as 0.9996% of missing values in it
# Movie12 as 0.999% of missing values in it
# Movie13 as 0.9998% of missing values in it
# Movie14 as 0.9998% of missing values in it
# Movie15 as 0.9998% of missing values in it
# Movie16 as 0.934% of missing values in it
# Movie17 as 0.9998% of missing values in it
# Movie18 as 0.9998% of missing values in it
# Movie19 as 0.9996% of missing values in it
# Movie20 as 0.9998% of missing values in it
# Movie21 as 0.9998% of missing values in it
# Movie22 as 0.9996% of missing values in it
# Movie23 as 0.9994% of missing values in it
# Movie24 as 0.999% of missing values in it
# Movie25 as 0.9998% of missing values in it
# Movie26 as 0.9994% of missing values in it
# Movie27 as 0.9998% of missing values in it
# Movie28 as 0.9994% of missing values in it
# Movie29 as 0.9499% of missing values in it
# Movie30 as 0.9996% of missing values in it
# Movie31 as 0.9996% of missing values in it
# Movie32 as 0.9996% of missing values in it
# Movie33 as 0.9998% of missing values in it
# Movie34 as 0.9998% of missing values in it
# Movie35 as 0.9998% of missing values in it
# Movie36 as 0.9998% of missing values in it
# Movie37 as 0.9998% of missing values in it
# Movie38 as 0.9998% of missing values in it
# Movie39 as 0.9992% of missing values in it
# Movie40 as 0.9994% of missing values in it
# Movie41 as 0.9998% of missing values in it
# Movie42 as 0.9998% of missing values in it
# Movie43 as 0.9986% of missing values in it
# Movie44 as 0.9996% of missing values in it
# Movie45 as 0.9998% of missing values in it
# Movie46 as 0.9998% of missing values in it
# Movie47 as 0.9998% of missing values in it
# Movie48 as 0.9998% of missing values in it
# Movie49 as 0.9998% of missing values in it
# Movie50 as 0.9998% of missing values in it
# Movie51 as 0.9996% of missing values in it
# Movie52 as 0.9965% of missing values in it
# Movie53 as 0.9994% of missing values in it
# Movie54 as 0.9998% of missing values in it
# Movie55 as 0.9998% of missing values in it
# Movie56 as 0.9998% of missing values in it
# Movie57 as 0.9998% of missing values in it
# Movie58 as 0.9998% of missing values in it
# Movie59 as 0.9998% of missing values in it
# Movie60 as 0.9998% of missing values in it
# Movie61 as 0.9998% of missing values in it
# Movie62 as 0.9992% of missing values in it
# Movie63 as 0.9998% of missing values in it
# Movie64 as 0.9998% of missing values in it
# Movie65 as 0.9998% of missing values in it
# Movie66 as 0.9998% of missing values in it
# Movie67 as 0.9998% of missing values in it
# Movie68 as 0.9998% of missing values in it
# Movie69 as 0.9998% of missing values in it
# Movie70 as 0.9996% of missing values in it
# Movie71 as 0.9998% of missing values in it
# Movie72 as 0.9998% of missing values in it
# Movie73 as 0.9998% of missing values in it
# Movie74 as 0.9998% of missing values in it
# Movie75 as 0.9998% of missing values in it
# Movie76 as 0.9996% of missing values in it
# Movie77 as 0.9998% of missing values in it
# Movie78 as 0.9998% of missing values in it
# Movie79 as 0.9996% of missing values in it
# Movie80 as 0.9998% of missing values in it
# Movie81 as 0.9975% of missing values in it
# Movie82 as 0.9996% of missing values in it
# Movie83 as 0.9998% of missing values in it
# Movie84 as 0.9998% of missing values in it
# Movie85 as 0.9994% of missing values in it
# Movie86 as 0.9957% of missing values in it
# Movie87 as 0.9998% of missing values in it
# Movie88 as 0.9998% of missing values in it
# Movie89 as 0.9829% of missing values in it
# Movie90 as 0.9963% of missing values in it
# Movie91 as 0.9736% of missing values in it
# Movie92 as 0.9792% of missing values in it
# Movie93 as 0.9996% of missing values in it
# Movie94 as 0.9994% of missing values in it
# Movie95 as 0.9988% of missing values in it
# Movie96 as 0.9994% of missing values in it
# Movie97 as 0.999% of missing values in it
# Movie98 as 0.9998% of missing values in it
# Movie99 as 0.9996% of missing values in it
# Movie100 as 0.9998% of missing values in it
# Movie101 as 0.999% of missing values in it
# Movie102 as 0.9996% of missing values in it
# Movie103 as 0.9439% of missing values in it
# Movie104 as 0.9992% of missing values in it
# Movie105 as 0.9994% of missing values in it
# Movie106 as 0.9998% of missing values in it
# Movie107 as 0.992% of missing values in it
# Movie108 as 0.9889% of missing values in it
# Movie109 as 0.9973% of missing values in it
# Movie110 as 0.9983% of missing values in it
# Movie111 as 0.992% of missing values in it
# Movie112 as 0.9996% of missing values in it
# Movie113 as 0.9992% of missing values in it
# Movie114 as 0.9986% of missing values in it
# Movie115 as 0.9998% of missing values in it
# Movie116 as 0.9998% of missing values in it
# Movie117 as 0.9977% of missing values in it
# Movie118 as 0.999% of missing values in it
# Movie119 as 0.9983% of missing values in it
# Movie120 as 0.9994% of missing values in it
# Movie121 as 0.9992% of missing values in it
# Movie122 as 0.9992% of missing values in it
# Movie123 as 0.9998% of missing values in it
# Movie124 as 0.9992% of missing values in it
# Movie125 as 0.999% of missing values in it
# Movie126 as 0.9996% of missing values in it
# Movie127 as 0.5229% of missing values in it
# Movie128 as 0.9994% of missing values in it
# Movie129 as 0.9994% of missing values in it
# Movie130 as 0.9992% of missing values in it
# Movie131 as 0.9992% of missing values in it
# Movie132 as 0.9994% of missing values in it
# Movie133 as 0.9998% of missing values in it
# Movie134 as 0.9988% of missing values in it
# Movie135 as 0.9998% of missing values in it
# Movie136 as 0.9996% of missing values in it
# Movie137 as 0.9994% of missing values in it
# Movie138 as 0.9973% of missing values in it
# Movie139 as 0.9992% of missing values in it
# Movie140 as 0.8808% of missing values in it
# Movie141 as 0.9986% of missing values in it
# Movie142 as 0.9998% of missing values in it
# Movie143 as 0.9998% of missing values in it
# Movie144 as 0.9998% of missing values in it
# Movie145 as 0.9998% of missing values in it
# Movie146 as 0.9998% of missing values in it
# Movie147 as 0.9998% of missing values in it
# Movie148 as 0.9996% of missing values in it
# Movie149 as 0.9998% of missing values in it
# Movie150 as 0.9994% of missing values in it
# Movie151 as 0.9996% of missing values in it
# Movie152 as 0.9998% of missing values in it
# Movie153 as 0.9998% of missing values in it
# Movie154 as 0.9998% of missing values in it
# Movie155 as 0.9996% of missing values in it
# Movie156 as 0.9998% of missing values in it
# Movie157 as 0.9992% of missing values in it
# Movie158 as 0.9864% of missing values in it
# Movie159 as 0.9996% of missing values in it
# Movie160 as 0.9988% of missing values in it
# Movie161 as 0.9948% of missing values in it
# Movie162 as 0.9969% of missing values in it
# Movie163 as 0.9973% of missing values in it
# Movie164 as 0.9992% of missing values in it
# Movie165 as 0.9998% of missing values in it
# Movie166 as 0.9996% of missing values in it
# Movie167 as 0.9992% of missing values in it
# Movie168 as 0.9992% of missing values in it
# Movie169 as 0.9992% of missing values in it
# Movie170 as 0.9994% of missing values in it
# Movie171 as 0.9998% of missing values in it
# Movie172 as 0.9996% of missing values in it
# Movie173 as 0.9969% of missing values in it
# Movie174 as 0.9992% of missing values in it
# Movie175 as 0.9998% of missing values in it
# Movie176 as 0.9998% of missing values in it
# Movie177 as 0.9998% of missing values in it
# Movie178 as 0.9998% of missing values in it
# Movie179 as 0.9986% of missing values in it
# Movie180 as 0.9998% of missing values in it
# Movie181 as 0.9996% of missing values in it
# Movie182 as 0.9938% of missing values in it
# Movie183 as 0.9998% of missing values in it
# Movie184 as 0.9965% of missing values in it
# Movie185 as 0.995% of missing values in it
# Movie186 as 0.9981% of missing values in it
# Movie187 as 0.9998% of missing values in it
# Movie188 as 0.9988% of missing values in it
# Movie189 as 0.999% of missing values in it
# Movie190 as 0.9986% of missing values in it
# Movie191 as 0.9988% of missing values in it
# Movie192 as 0.9979% of missing values in it
# Movie193 as 0.9986% of missing values in it
# Movie194 as 0.9986% of missing values in it
# Movie195 as 0.9998% of missing values in it
# Movie196 as 0.9981% of missing values in it
# Movie197 as 0.999% of missing values in it
# Movie198 as 0.9996% of missing values in it
# Movie199 as 0.9998% of missing values in it
# Movie200 as 0.9983% of missing values in it
# Movie201 as 0.9994% of missing values in it
# Movie202 as 0.9988% of missing values in it
# Movie203 as 0.9998% of missing values in it
# Movie204 as 0.9983% of missing values in it
# Movie205 as 0.9928% of missing values in it
# Movie206 as 0.9973% of missing values in it

# %%
amazon_data.describe().T.head()
# Out:
#         count      mean       std  min  25%  50%  75%  max
# Movie1    1.0  5.000000       NaN  5.0  5.0  5.0  5.0  5.0
# Movie2    1.0  5.000000       NaN  5.0  5.0  5.0  5.0  5.0
# Movie3    1.0  2.000000       NaN  2.0  2.0  2.0  2.0  2.0
# Movie4    2.0  5.000000  0.000000  5.0  5.0  5.0  5.0  5.0
# Movie5   29.0  4.103448  1.496301  1.0  4.0  5.0  5.0  5.0

# %% [markdown]
# ### Exploratory Data Analysis Task :

# %% [markdown]
# #### Which movies have maximum views/ratings?

# %%
#movie with maximum views?
amazon_data.describe().T['count'].sort_values(ascending=False)[:1].to_frame()
# Out:
#            count
# Movie127  2313.0

# %% [markdown]
# _**Movie127** has maximum views with a count of **2313.0**_

# %%
#movie with maximum ratings
amazon_data.drop('user_id',axis=1).sum().sort_values(ascending=False)[:1].to_frame()
# Out:
#                0
# Movie127  9511.0

# %% [markdown]
# _**Movie127** has maximum rating with a sum of **9511.0**_

# %% [markdown]
# #### What is the average rating for each movie? Define the top 5 movies with the maximum ratings.

# %%
#average rating of each movie
amazon_data.drop('user_id',axis=1).mean()
# Out:
# Movie1      5.000000
# Movie2      5.000000
# Movie3      2.000000
# Movie4      5.000000
# Movie5      4.103448
#               ...
# Movie202    4.333333
# Movie203    3.000000
# Movie204    4.375000
# Movie205    4.628571
# Movie206    4.923077
# Length: 206, dtype: float64

# %%
#top 5 movies with the maximum ratings
amazon_data.drop('user_id',axis=1).mean().sort_values(ascending=False)[:5].to_frame()
# Out:
#             0
# Movie1    5.0
# Movie55   5.0
# Movie131  5.0
# Movie132  5.0
# Movie133  5.0

# %% [markdown]
# _**Movie1,Movie55,Movie131,Movie132,Movie133** are the top 5 movies with maximum ratings on an average_

# %% [markdown]
# #### Define the top 5 movies with the least audience.

# %%
amazon_data.describe().T['count'].sort_values(ascending=True)[:5].to_frame()
# Out:
#           count
# Movie1      1.0
# Movie71     1.0
# Movie145    1.0
# Movie69     1.0
# Movie68     1.0

# %% [markdown]
# _**Movie1,Movie71,Movie145,Movie69,Movie68** are the top 5 movies with the  least audience_

# %% [markdown]
# ### Recommendation Model :

# %% [markdown]
# #### Importing libiraries required for model building

# %%
from surprise import Reader
from surprise import Dataset
from surprise.model_selection import train_test_split
from surprise import SVD
from surprise import accuracy
from surprise.model_selection import cross_validate

# %%
movies_data = amazon_data.melt(id_vars = amazon_data.columns[0],value_vars=amazon_data.columns[1:],var_name="Movies",value_name="Rating")
movies_data.head()
# Out:
#           user_id  Movies  Rating
# 0  A3R5OBKS7OM2IR  Movie1     5.0
# 1   AH3QC2PC1VTGP  Movie1     NaN
# 2  A3LKP6WPMP9UKX  Movie1     NaN
# 3   AVIY68KEPQ5ZD  Movie1     NaN
# 4  A1CV1WROP5KTTW  Movie1     NaN

# %%
#reading the dataset
rd = Reader(rating_scale=(-1,10))
data = Dataset.load_from_df(movies_data.fillna(0),reader=rd)

# %%
#splitting the dataset
train_data,test_data = train_test_split(data,random_state=10)

# %%
#creating SVD (Singular Value Descomposition) object
svd = SVD()
svd.fit(train_data)

# %%
preds = svd.test(test_data)

# %%
preds[:5]
# Out:
# [Prediction(uid='A3EJVZ5LCBP61X', iid='Movie153', r_ui=0.0, est=0.0069878860151298015, details={'was_impossible': False}),
#  Prediction(uid='A3LCW5H7XK5B22', iid='Movie158', r_ui=0.0, est=0.2817704759799421, details={'was_impossible': False}),
#  Prediction(uid='A3KGYTO6CF8MGF', iid='Movie99', r_ui=0.0, est=0.006140894879915938, details={'was_impossible': False}),
#  Prediction(uid='A2869WCKQA2NNW', iid='Movie40', r_ui=0.0, est=0.005542913593096648, details={'was_impossible': False}),
#  Prediction(uid='A1897EYRUTMKKI', iid='Movie9', r_ui=0.0, est=0.007377839720217094, details={'was_impossible': False})]

# %%
#checking for rmse accuracy
accuracy.rmse(preds)
# Out:
# RMSE: 0.2781
# 0.2781421541974895

# %%
#checking for mae accuracy
accuracy.mae(preds)
# Out:
# MAE:  0.0409
# 0.040881756868222

# %%
u_id='A3GUOAL2MF4IYT'
iid = 'Movie197'
r_ui = 5.0
svd.predict(u_id,iid,r_ui,verbose= True)
# Out:
# user: A3GUOAL2MF4IYT item: Movie197   r_ui = 5.00   est = -0.01   {'was_impossible': False}
# Prediction(uid='A3GUOAL2MF4IYT', iid='Movie197', r_ui=5.0, est=-0.008017731571423764, details={'was_impossible': False})

# %%
cross_validate(svd, data, measures = ['RMSE', 'MAE'], cv = 3, verbose = True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.2823  0.2818  0.2830  0.2824  0.0005
# MAE (testset)     0.0425  0.0430  0.0427  0.0427  0.0002
# Fit time          45.30   44.89   45.62   45.27   0.30
# Test time         3.69    4.32    4.36    4.12    0.31
# {'test_rmse': array([0.28229661, 0.28182134, 0.28304456]),
#  'test_mae': array([0.04252376, 0.04300189, 0.04271283]),
#  'fit_time': (45.30189538002014, 44.89337229728699, 45.62289333343506),
#  'test_time': (3.6939566135406494, 4.317623853683472, 4.362195253372192)}

# %%
def repeat(ml_type,df,min_,max_):
    rd = Reader()
    data = Dataset.load_from_df(df,reader=rd)
    print(cross_validate(ml_type, data, measures = ['RMSE', 'MAE'], cv = 3, verbose = True))
    print("________"*20)
    u_id = 'A3GUOAL2MF4IYT'
    iid = 'Movie197'
    r_ui = 5.0
    print(ml_type.predict(u_id,iid,r_ui,verbose=True))
    print("________"*20)
    print()

# %%
amazon_data= amazon_data.iloc[:3000, :50]
movies_data = amazon_data.melt(id_vars = amazon_data.columns[0],value_vars=amazon_data.columns[1:],var_name="Movies",value_name="Rating")

# %%
repeat(SVD(),movies_data.fillna(0),-1,10)
repeat(SVD(),movies_data.fillna(movies_data.mean()),-1,10)
repeat(SVD(),movies_data.fillna(movies_data.median()),-1,10)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0254  1.0306  1.0315  1.0292  0.0027
# MAE (testset)     1.0110  1.0130  1.0135  1.0125  0.0011
# Fit time          7.19    7.53    7.26    7.33    0.15
# Test time         0.48    0.48    1.21    0.72    0.34
# {'test_rmse': array([1.02542717, 1.03056233, 1.03154472]), 'test_mae': array([1.01101869, 1.0129967 , 1.01350196]), 'fit_time': (7.1880035400390625, 7.530601739883423, 7.2649760246276855), 'test_time': (0.4804365634918213, 0.4755537509918213, 1.2091670036315918)}
# ________________________________________________________________________________________________________________________________________________________________
# user: A3GUOAL2MF4IYT item: Movie197   r_ui = 5.00   est = 1.00   {'was_impossible': False}
# user: A3GUOAL2MF4IYT item: Movie197   r_ui = 5.00   est = 1.00   {'was_impossible': False}
# ________________________________________________________________________________________________________________________________________________________________
#
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.0519  0.0558  0.0632  0.0570  0.0047
# MAE (testset)     0.0071  0.0078  0.0077  0.0075  0.0003
# Fit time          6.87    6.94    7.23    7.01    0.15
# Test time         0.48    0.54    1.13    0.72    0.29
# {'test_rmse': array([0.05189532, 0.05580978, 0.06317722]), 'test_mae': array([0.00707554, 0.007784  , 0.00770269]), 'fit_time': (6.872145175933838, 6.9447925090789795, 7.2250330448150635), 'test_time': (0.4777252674102783, 0.5443606376647949, 1.1281578540802002)}
# ________________________________________________________________________________________________________________________________________________________________
# user: A3GUOAL2MF4IYT item: Movie197   r_ui = 5.00   est = 4.61   {'was_impossible': False}
# user: A3GUOAL2MF4IYT item: Movie197   r_ui = 5.00   est = 4.61   {'was_impossible': False}
# ________________________________________________________________________________________________________________________________________________________________
#
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.0540  0.0661  0.0662  0.0621  0.0058
# MAE (testset)     0.0052  0.0054  0.0054  0.0053  0.0001
# Fit time          6.92    6.76    6.98    6.89    0.09
# Test time         0.49    0.44    0.47    0.47    0.02
# {'test_rmse': array([0.05397441, 0.06610724, 0.06624825]), 'test_mae': array([0.00521448, 0.0054364 , 0.00536468]), 'fit_time': (6.923963785171509, 6.755669593811035, 6.978619575500488), 'test_time': (0.4882485866546631, 0.44281649589538574, 0.46985864639282227)}
# ________________________________________________________________________________________________________________________________________________________________
# user: A3GUOAL2MF4IYT item: Movie197   r_ui = 5.00   est = 5.00   {'was_impossible': False}
# user: A3GUOAL2MF4IYT item: Movie197   r_ui = 5.00   est = 5.00   {'was_impossible': False}
# ________________________________________________________________________________________________________________________________________________________________

# %%
#using grid search to find the optimum hyperparameter value for n_factors
from surprise.model_selection import GridSearchCV

# %%
params = {'n_epochs':[20,30],
             'lr_all':[0.005,0.001],
             'n_factors':[50,100]}

# %%
GS = GridSearchCV(SVD,params,measures=['rmse','mae'],cv=3)
GS.fit(data)

# %%
GS.best_score
# Out:
# {'rmse': 0.2798426572690132, 'mae': 0.041522030061130095}

# %%
print(GS.best_params["rmse"])
print(GS.best_score["rmse"])
# Out:
# {'n_epochs': 30, 'lr_all': 0.005, 'n_factors': 50}
# 0.2798426572690132
